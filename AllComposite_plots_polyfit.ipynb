# %% [markdown]
# ### Read the 2 output excels here polyfit 15 and 30 yr

# %%
import pandas as pd
import numpy as np
from scipy.stats import linregress
from datetime import datetime
path = '/data/keeling/a/sudhansu/i/GlobalTempChange'

# %% [markdown]
# ### polyfit_15year trend data for plotting

# %%
df_noaa = pd.read_excel(path+'/GlobalTemperature_polyfit_15yrTrend.xlsx', sheet_name='NOAA')
df_crut = pd.read_excel(path+'/GlobalTemperature_polyfit_15yrTrend.xlsx', sheet_name='HadCRUT')
df_berkeley = pd.read_excel(path+'/GlobalTemperature_polyfit_15yrTrend.xlsx', sheet_name='Berkeley-Earth-Temperature')
df_NASA = pd.read_excel(path+'/GlobalTemperature_polyfit_15yrTrend.xlsx', sheet_name='NASA')
df_DCENT = pd.read_excel(path+'/GlobalTemperature_polyfit_15yrTrend.xlsx', sheet_name='DCENT_GlobalTemperature')

# %% [markdown]
# ### polyfit 15 yr trend plot

# %%
from matplotlib.ticker import AutoMinorLocator

import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))

# Plot df_noaa
plt.plot(df_noaa['Year'], df_noaa['Anomaly(1850-1900 baseline)'], label='NOAA Anomaly', color='#1f77b4', linewidth=2)
plt.plot(df_noaa['Year'], df_noaa['31yr_centered_avg'], label='NOAA 31yr Centered Avg', linestyle='--', color='#1f77b4', linewidth=2)

# Plot df_crut
plt.plot(df_crut['Time'], df_crut['Anomaly(1850-1900 baseline)'], label='CRUT Anomaly', color='#ff7f0e', linewidth=2)
plt.plot(df_crut['Time'], df_crut['31yr_centered_avg'], label='CRUT 31yr Centered Avg', linestyle='--', color='#ff7f0e', linewidth=2)

# Plot df_berkeley
plt.plot(df_berkeley['Year'], df_berkeley['Anomaly(1850-1900 baseline)'], label='Berkeley Anomaly', color='#2ca02c', linewidth=2)
plt.plot(df_berkeley['Year'], df_berkeley['31yr_centered_avg'], label='Berkeley 31yr Centered Avg', linestyle='--', color='#2ca02c', linewidth=2)

# Plot df_NASA
plt.plot(df_NASA['Year'], df_NASA['Anomaly(1850-1900 baseline)'], label='NASA Anomaly', color='#d62728', linewidth=2)
plt.plot(df_NASA['Year'], df_NASA['31yr_centered_avg'], label='NASA 31yr Centered Avg', linestyle='--', color='#d62728', linewidth=2)

# Plot df_DCENT
plt.plot(df_DCENT['Year'], df_DCENT['Anomaly(1850-1900 baseline)'], label='DCENT Anomaly', color='#9467bd', linewidth=2)
plt.plot(df_DCENT['Year'], df_DCENT['31yr_centered_avg'], label='DCENT 31yr Centered Avg', linestyle='--', color='#9467bd', linewidth=2)

# Add grid lines
plt.grid(True, linestyle='-', alpha=0.5, axis='y', which='both', color='gray')

# Remove y-axis line and tick marks
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().yaxis.set_ticks([])

# Move legend slightly down
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=2, frameon=False, fontsize=14)

# Add a horizontal line at y=1.5
plt.axhline(y=1.5, color='orange', linestyle='--', label='y=1.5')

# Add a horizontal line at y=2.0
plt.axhline(y=2.0, color='r', linestyle='--', label='y=2.0')

# Set x-axis limit
plt.xlim([1850, 2050])
plt.ylim([-1, 2.5])

# Set x-axis ticks and labels at 5-year intervals
plt.xticks(range(1850, 2051, 20), fontsize=14)

# Set y-axis ticks at 0.5 intervals
plt.yticks([i * 0.5 for i in range(-1, 5)], fontsize=14)
plt.gca().xaxis.set_minor_locator(AutoMinorLocator())

plt.tick_params(which='both', width=2)
plt.tick_params(which='major', length=7)
plt.tick_params(which='minor', length=4, color='r')

# Add title and labels
plt.title('Estimated Anomaly (15-Year Trend and 31-Year Centered Average)', fontsize=18)
plt.xlabel('Year', fontsize=16)
plt.ylabel(u'Anomaly in (\u00B0C)(1850-1900 baseline)', fontsize=16)

# Add annotation
plt.annotate('Estimated using a 15-year trend', xy=(2020, 1), xytext=(1995, 0.25),
             arrowprops=dict(facecolor='black', shrink=0.05),
             fontsize=14, color='black',
             bbox=dict(boxstyle='round,pad=0.5', edgecolor='black', facecolor='white'))

# Show plot
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))

# Plot df_noaa
plt.plot(df_noaa['Year'], df_noaa['Anomaly(1850-1900 baseline)'], label='NOAA Anomaly', color='#1f77b4', linewidth=2)
plt.plot(df_noaa['Year'], df_noaa['21yr_centered_avg'], label='NOAA 21yr Centered Avg', linestyle='--', color='#1f77b4', linewidth=2)

# Plot df_crut
plt.plot(df_crut['Time'], df_crut['Anomaly(1850-1900 baseline)'], label='CRUT Anomaly', color='#ff7f0e', linewidth=2)
plt.plot(df_crut['Time'], df_crut['21yr_centered_avg'], label='CRUT 21yr Centered Avg', linestyle='--', color='#ff7f0e', linewidth=2)

# Plot df_berkeley
plt.plot(df_berkeley['Year'], df_berkeley['Anomaly(1850-1900 baseline)'], label='Berkeley Anomaly', color='#2ca02c', linewidth=2)
plt.plot(df_berkeley['Year'], df_berkeley['21yr_centered_avg'], label='Berkeley 21yr Centered Avg', linestyle='--', color='#2ca02c', linewidth=2)

# Plot df_NASA
plt.plot(df_NASA['Year'], df_NASA['Anomaly(1850-1900 baseline)'], label='NASA Anomaly', color='#d62728', linewidth=2)
plt.plot(df_NASA['Year'], df_NASA['21yr_centered_avg'], label='NASA 21yr Centered Avg', linestyle='--', color='#d62728', linewidth=2)

# Plot df_DCENT
plt.plot(df_DCENT['Year'], df_DCENT['Anomaly(1850-1900 baseline)'], label='DCENT Anomaly', color='#9467bd', linewidth=2)
plt.plot(df_DCENT['Year'], df_DCENT['21yr_centered_avg'], label='DCENT 21yr Centered Avg', linestyle='--', color='#9467bd', linewidth=2)

# Add grid lines
plt.grid(True, linestyle='-', alpha=0.5, axis='y', which='both', color='gray')

# Remove y-axis line and tick marks
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().yaxis.set_ticks([])

# Move legend slightly down
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=2, frameon=False, fontsize=14)

# Add a horizontal line at y=1.5
plt.axhline(y=1.5, color='orange', linestyle='--', label='y=1.5')

# Add a horizontal line at y=2.0
plt.axhline(y=2.0, color='r', linestyle='--', label='y=2.0')

# Set x-axis limit
plt.xlim([1850, 2050])
plt.ylim([-1, 2.5])

# Set x-axis ticks and labels at 5-year intervals
plt.xticks(range(1850, 2051, 20), fontsize=14)

# Set y-axis ticks at 0.5 intervals
plt.yticks([i * 0.5 for i in range(-1, 5)], fontsize=14)
plt.gca().xaxis.set_minor_locator(AutoMinorLocator())

plt.tick_params(which='both', width=2)
plt.tick_params(which='major', length=7)
plt.tick_params(which='minor', length=4, color='r')

# Add title and labels
plt.title('Estimated Anomaly (15-Year Trend and 21-Year Centered Average)', fontsize=18)
plt.xlabel('Year', fontsize=16)
plt.ylabel(u'Anomaly in (\u00B0C)(1850-1900 baseline)', fontsize=16)

# Add annotation
plt.annotate('Estimated using a 15-year trend', xy=(2020, 1), xytext=(1995, 0.25),
             arrowprops=dict(facecolor='black', shrink=0.05),
             fontsize=14, color='black',
             bbox=dict(boxstyle='round,pad=0.5', edgecolor='black', facecolor='white'))

# Show plot
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))

# Plot df_noaa
plt.plot(df_noaa['Year'], df_noaa['Anomaly(1850-1900 baseline)'], label='NOAA Anomaly', color='#1f77b4', linewidth=2)
plt.plot(df_noaa['Year'], df_noaa['11yr_centered_avg'], label='NOAA 11yr Centered Avg', linestyle='--', color='#1f77b4', linewidth=2)

# Plot df_crut
plt.plot(df_crut['Time'], df_crut['Anomaly(1850-1900 baseline)'], label='CRUT Anomaly', color='#ff7f0e', linewidth=2)
plt.plot(df_crut['Time'], df_crut['11yr_centered_avg'], label='CRUT 11yr Centered Avg', linestyle='--', color='#ff7f0e', linewidth=2)

# Plot df_berkeley
plt.plot(df_berkeley['Year'], df_berkeley['Anomaly(1850-1900 baseline)'], label='Berkeley Anomaly', color='#2ca02c', linewidth=2)
plt.plot(df_berkeley['Year'], df_berkeley['11yr_centered_avg'], label='Berkeley 11yr Centered Avg', linestyle='--', color='#2ca02c', linewidth=2)

# Plot df_NASA
plt.plot(df_NASA['Year'], df_NASA['Anomaly(1850-1900 baseline)'], label='NASA Anomaly', color='#d62728', linewidth=2)
plt.plot(df_NASA['Year'], df_NASA['11yr_centered_avg'], label='NASA 11yr Centered Avg', linestyle='--', color='#d62728', linewidth=2)

# Plot df_DCENT
plt.plot(df_DCENT['Year'], df_DCENT['Anomaly(1850-1900 baseline)'], label='DCENT Anomaly', color='#9467bd', linewidth=2)
plt.plot(df_DCENT['Year'], df_DCENT['11yr_centered_avg'], label='DCENT 11yr Centered Avg', linestyle='--', color='#9467bd', linewidth=2)

# Add grid lines
plt.grid(True, linestyle='-', alpha=0.5, axis='y', which='both', color='gray')

# Remove y-axis line and tick marks
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().yaxis.set_ticks([])

# Move legend slightly down
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=2, frameon=False, fontsize=14)

# Add a horizontal line at y=1.5
plt.axhline(y=1.5, color='orange', linestyle='--', label='y=1.5')

# Add a horizontal line at y=2.0
plt.axhline(y=2.0, color='r', linestyle='--', label='y=2.0')

# Set x-axis limit
plt.xlim([1850, 2050])
plt.ylim([-1, 2.5])

# Set x-axis ticks and labels at 5-year intervals
plt.xticks(range(1850, 2051, 20), fontsize=14)

# Set y-axis ticks at 0.5 intervals
plt.yticks([i * 0.5 for i in range(-1, 5)], fontsize=14)
plt.gca().xaxis.set_minor_locator(AutoMinorLocator())

plt.tick_params(which='both', width=2)
plt.tick_params(which='major', length=7)
plt.tick_params(which='minor', length=4, color='r')

# Add title and labels
plt.title('Estimated Anomaly (15-Year Trend and 11-Year Centered Average)', fontsize=18)
plt.xlabel('Year', fontsize=16)
plt.ylabel(u'Anomaly in (\u00B0C)(1850-1900 baseline)', fontsize=16)

# Add annotation
plt.annotate('Estimated using an 15-year trend', xy=(2020, 1), xytext=(1995, 0.25),
             arrowprops=dict(facecolor='black', shrink=0.05),
             fontsize=14, color='black',
             bbox=dict(boxstyle='round,pad=0.5', edgecolor='black', facecolor='white'))

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Linear 30 yr trend plot

# %%
df_noaa = pd.read_excel(path+'/GlobalTemperature_polyfit_30yrTrend.xlsx', sheet_name='NOAA')
df_crut = pd.read_excel(path+'/GlobalTemperature_polyfit_30yrTrend.xlsx', sheet_name='HadCRUT')
df_berkeley = pd.read_excel(path+'/GlobalTemperature_polyfit_30yrTrend.xlsx', sheet_name='Berkeley-Earth-Temperature')
df_NASA = pd.read_excel(path+'/GlobalTemperature_polyfit_30yrTrend.xlsx', sheet_name='NASA')
df_DCENT = pd.read_excel(path+'/GlobalTemperature_polyfit_30yrTrend.xlsx', sheet_name='DCENT_GlobalTemperature')

# %%
from matplotlib.ticker import AutoMinorLocator

import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))

# Plot df_noaa
plt.plot(df_noaa['Year'], df_noaa['Anomaly(1850-1900 baseline)'], label='NOAA Anomaly', color='#1f77b4', linewidth=2)
plt.plot(df_noaa['Year'], df_noaa['31yr_centered_avg'], label='NOAA 31yr Centered Avg', linestyle='--', color='#1f77b4', linewidth=2)

# Plot df_crut
plt.plot(df_crut['Time'], df_crut['Anomaly(1850-1900 baseline)'], label='CRUT Anomaly', color='#ff7f0e', linewidth=2)
plt.plot(df_crut['Time'], df_crut['31yr_centered_avg'], label='CRUT 31yr Centered Avg', linestyle='--', color='#ff7f0e', linewidth=2)

# Plot df_berkeley
plt.plot(df_berkeley['Year'], df_berkeley['Anomaly(1850-1900 baseline)'], label='Berkeley Anomaly', color='#2ca02c', linewidth=2)
plt.plot(df_berkeley['Year'], df_berkeley['31yr_centered_avg'], label='Berkeley 31yr Centered Avg', linestyle='--', color='#2ca02c', linewidth=2)

# Plot df_NASA
plt.plot(df_NASA['Year'], df_NASA['Anomaly(1850-1900 baseline)'], label='NASA Anomaly', color='#d62728', linewidth=2)
plt.plot(df_NASA['Year'], df_NASA['31yr_centered_avg'], label='NASA 31yr Centered Avg', linestyle='--', color='#d62728', linewidth=2)

# Plot df_DCENT
plt.plot(df_DCENT['Year'], df_DCENT['Anomaly(1850-1900 baseline)'], label='DCENT Anomaly', color='#9467bd', linewidth=2)
plt.plot(df_DCENT['Year'], df_DCENT['31yr_centered_avg'], label='DCENT 31yr Centered Avg', linestyle='--', color='#9467bd', linewidth=2)

# Add grid lines
plt.grid(True, linestyle='-', alpha=0.5, axis='y', which='both', color='gray')

# Remove y-axis line and tick marks
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().yaxis.set_ticks([])

# Move legend slightly down
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=2, frameon=False, fontsize=14)

# Add a horizontal line at y=1.5
plt.axhline(y=1.5, color='orange', linestyle='--', label='y=1.5')

# Add a horizontal line at y=2.0
plt.axhline(y=2.0, color='r', linestyle='--', label='y=2.0')

# Set x-axis limit
plt.xlim([1850, 2050])
plt.ylim([-1, 2.5])

# Set x-axis ticks and labels at 5-year intervals
plt.xticks(range(1850, 2051, 20), fontsize=14)

# Set y-axis ticks at 0.5 intervals
plt.yticks([i * 0.5 for i in range(-1, 5)], fontsize=14)
plt.gca().xaxis.set_minor_locator(AutoMinorLocator())

plt.tick_params(which='both', width=2)
plt.tick_params(which='major', length=7)
plt.tick_params(which='minor', length=4, color='r')

# Add title and labels
plt.title('Estimated Anomaly (30-Year Trend and 31-Year Centered Average)', fontsize=18)
plt.xlabel('Year', fontsize=16)
plt.ylabel(u'Anomaly in (\u00B0C)(1850-1900 baseline)', fontsize=16)

# Add annotation
plt.annotate('Estimated using a 30-year trend', xy=(2020, 1), xytext=(1995, 0.25),
             arrowprops=dict(facecolor='black', shrink=0.05),
             fontsize=14, color='black',
             bbox=dict(boxstyle='round,pad=0.5', edgecolor='black', facecolor='white'))

# Show plot
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))

# Plot df_noaa
plt.plot(df_noaa['Year'], df_noaa['Anomaly(1850-1900 baseline)'], label='NOAA Anomaly', color='#1f77b4', linewidth=2)
plt.plot(df_noaa['Year'], df_noaa['21yr_centered_avg'], label='NOAA 21yr Centered Avg', linestyle='--', color='#1f77b4', linewidth=2)

# Plot df_crut
plt.plot(df_crut['Time'], df_crut['Anomaly(1850-1900 baseline)'], label='CRUT Anomaly', color='#ff7f0e', linewidth=2)
plt.plot(df_crut['Time'], df_crut['21yr_centered_avg'], label='CRUT 21yr Centered Avg', linestyle='--', color='#ff7f0e', linewidth=2)

# Plot df_berkeley
plt.plot(df_berkeley['Year'], df_berkeley['Anomaly(1850-1900 baseline)'], label='Berkeley Anomaly', color='#2ca02c', linewidth=2)
plt.plot(df_berkeley['Year'], df_berkeley['21yr_centered_avg'], label='Berkeley 21yr Centered Avg', linestyle='--', color='#2ca02c', linewidth=2)

# Plot df_NASA
plt.plot(df_NASA['Year'], df_NASA['Anomaly(1850-1900 baseline)'], label='NASA Anomaly', color='#d62728', linewidth=2)
plt.plot(df_NASA['Year'], df_NASA['21yr_centered_avg'], label='NASA 21yr Centered Avg', linestyle='--', color='#d62728', linewidth=2)

# Plot df_DCENT
plt.plot(df_DCENT['Year'], df_DCENT['Anomaly(1850-1900 baseline)'], label='DCENT Anomaly', color='#9467bd', linewidth=2)
plt.plot(df_DCENT['Year'], df_DCENT['21yr_centered_avg'], label='DCENT 21yr Centered Avg', linestyle='--', color='#9467bd', linewidth=2)

# Add grid lines
plt.grid(True, linestyle='-', alpha=0.5, axis='y', which='both', color='gray')

# Remove y-axis line and tick marks
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().yaxis.set_ticks([])

# Move legend slightly down
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=2, frameon=False, fontsize=14)

# Add a horizontal line at y=1.5
plt.axhline(y=1.5, color='orange', linestyle='--', label='y=1.5')

# Add a horizontal line at y=2.0
plt.axhline(y=2.0, color='r', linestyle='--', label='y=2.0')

# Set x-axis limit
plt.xlim([1850, 2050])
plt.ylim([-1, 2.5])

# Set x-axis ticks and labels at 5-year intervals
plt.xticks(range(1850, 2051, 20), fontsize=14)

# Set y-axis ticks at 0.5 intervals
plt.yticks([i * 0.5 for i in range(-1, 5)], fontsize=14)
plt.gca().xaxis.set_minor_locator(AutoMinorLocator())

plt.tick_params(which='both', width=2)
plt.tick_params(which='major', length=7)
plt.tick_params(which='minor', length=4, color='r')

# Add title and labels
plt.title('Estimated Anomaly (30-Year Trend and 21-Year Centered Average)', fontsize=18)
plt.xlabel('Year', fontsize=16)
plt.ylabel(u'Anomaly in (\u00B0C)(1850-1900 baseline)', fontsize=16)

# Add annotation
plt.annotate('Estimated using a 30-year trend', xy=(2020, 1), xytext=(1995, 0.25),
             arrowprops=dict(facecolor='black', shrink=0.05),
             fontsize=14, color='black',
             bbox=dict(boxstyle='round,pad=0.5', edgecolor='black', facecolor='white'))

# Show plot
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))

# Plot df_noaa
plt.plot(df_noaa['Year'], df_noaa['Anomaly(1850-1900 baseline)'], label='NOAA Anomaly', color='#1f77b4', linewidth=2)
plt.plot(df_noaa['Year'], df_noaa['11yr_centered_avg'], label='NOAA 11yr Centered Avg', linestyle='--', color='#1f77b4', linewidth=2)

# Plot df_crut
plt.plot(df_crut['Time'], df_crut['Anomaly(1850-1900 baseline)'], label='CRUT Anomaly', color='#ff7f0e', linewidth=2)
plt.plot(df_crut['Time'], df_crut['11yr_centered_avg'], label='CRUT 11yr Centered Avg', linestyle='--', color='#ff7f0e', linewidth=2)

# Plot df_berkeley
plt.plot(df_berkeley['Year'], df_berkeley['Anomaly(1850-1900 baseline)'], label='Berkeley Anomaly', color='#2ca02c', linewidth=2)
plt.plot(df_berkeley['Year'], df_berkeley['11yr_centered_avg'], label='Berkeley 11yr Centered Avg', linestyle='--', color='#2ca02c', linewidth=2)

# Plot df_NASA
plt.plot(df_NASA['Year'], df_NASA['Anomaly(1850-1900 baseline)'], label='NASA Anomaly', color='#d62728', linewidth=2)
plt.plot(df_NASA['Year'], df_NASA['11yr_centered_avg'], label='NASA 11yr Centered Avg', linestyle='--', color='#d62728', linewidth=2)

# Plot df_DCENT
plt.plot(df_DCENT['Year'], df_DCENT['Anomaly(1850-1900 baseline)'], label='DCENT Anomaly', color='#9467bd', linewidth=2)
plt.plot(df_DCENT['Year'], df_DCENT['11yr_centered_avg'], label='DCENT 11yr Centered Avg', linestyle='--', color='#9467bd', linewidth=2)

# Add grid lines
plt.grid(True, linestyle='-', alpha=0.5, axis='y', which='both', color='gray')

# Remove y-axis line and tick marks
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().yaxis.set_ticks([])

# Move legend slightly down
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=2, frameon=False, fontsize=14)

# Add a horizontal line at y=1.5
plt.axhline(y=1.5, color='orange', linestyle='--', label='y=1.5')

# Add a horizontal line at y=2.0
plt.axhline(y=2.0, color='r', linestyle='--', label='y=2.0')

# Set x-axis limit
plt.xlim([1850, 2050])
plt.ylim([-1, 2.5])

# Set x-axis ticks and labels at 5-year intervals
plt.xticks(range(1850, 2051, 20), fontsize=14)

# Set y-axis ticks at 0.5 intervals
plt.yticks([i * 0.5 for i in range(-1, 5)], fontsize=14)
plt.gca().xaxis.set_minor_locator(AutoMinorLocator())

plt.tick_params(which='both', width=2)
plt.tick_params(which='major', length=7)
plt.tick_params(which='minor', length=4, color='r')

# Add title and labels
plt.title('Estimated Anomaly (30-Year Trend and 11-Year Centered Average)', fontsize=18)
plt.xlabel('Year', fontsize=16)
plt.ylabel(u'Anomaly in (\u00B0C)(1850-1900 baseline)', fontsize=16)

# Add annotation
plt.annotate('Estimated using an 30-year trend', xy=(2020, 1), xytext=(1995, 0.25),
             arrowprops=dict(facecolor='black', shrink=0.05),
             fontsize=14, color='black',
             bbox=dict(boxstyle='round,pad=0.5', edgecolor='black', facecolor='white'))

# Show plot
plt.tight_layout()
plt.show()
